# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.chdir('/home/srikant/Downloads/')

# %%
image=cv2.imread('application_form-81495be0-162-1.jpg')

# %%
imgray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image)
size=(1700,2338)
thresh = cv2.resize(image, size, interpolation = cv2.INTER_AREA)

# %%
cropped_emailid = thresh[1215:1270, 170:1671]
plt.imshow(cropped_emailid)

# %%
dob_pred="85078004"

# %%
date=list(dob_pred)

# %%
date[4] = '1'
date[5] = '9'

# %%
 if int(date[0]) > 2:
        date[0] = '2'

# %%
if int(date[2]) > 1:
    if int(date[3])>2:
        date[2] = '0'
    else:
        date[2] = '1'

# %%
date
# Out:
# ['2', '5', '0', '7', '1', '9', '0', '4']

# %%
dob_pre = ''.join(date)

# %%
dob_pre
# Out:
# '25071904'

# %%
 dobpre=dob_pre[:2]+'/'+dob_pre[2:4]+'/'+dob_pre[4:]

# %%
dobpre
# Out:
# '25/07/1904'

# %%
dob_pre
# Out:
# '25071904'
